# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishShinde03/DataSciencePractice/blob/main/Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scrapping

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "tv"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(flipkart_url)

# %%
urlclient

# %%
flipkart_page = urlclient.read()

# %%
flipkart_html = bs(flipkart_page, 'html.parser')

# %%
bigbox = flipkart_html.find_all("div", {"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
del bigbox[0:3]

# %%
len(bigbox)
# Out:
# 27

# %%
product_link_href = bigbox[0].div.div.div.a['href']

# %%
product_link_href
# Out:
# '/samsung-80-cm-32-inch-hd-ready-led-smart-tizen-tv-2022-model/p/itm3c07ddc2dd25d?pid=TVSGHY2UZA9YHWQN&lid=LSTTVSGHY2UZA9YHWQNNQENTU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_H%2Ft1lVEmk5dG9Nh2WP4xGa987HtKQ%2F2Mh2fTcF92cwZEaLk1rTtsGNE8ePQkeIjzKUXLsS6xKC1eMMA2CJL5Kg%3D%3D&ppt=None&ppn=None&ssid=yo3wkd98gw0000001679959275842&qH=c9a1fdac6e082dd8'

# %%
product_link = flipkart_url + product_link_href

# %%
for i in bigbox:
  print("https://www.flipkart.com" + i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/samsung-80-cm-32-inch-hd-ready-led-smart-tizen-tv-2022-model/p/itm3c07ddc2dd25d?pid=TVSGHY2UZA9YHWQN&lid=LSTTVSGHY2UZA9YHWQNNQENTU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_H%2Ft1lVEmk5dG9Nh2WP4xGa987HtKQ%2F2Mh2fTcF92cwZEaLk1rTtsGNE8ePQkeIjzKUXLsS6xKC1eMMA2CJL5Kg%3D%3D&ppt=None&ppn=None&ssid=yo3wkd98gw0000001679959275842&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/oneplus-y1-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio/p/itme650a6bb8cee3?pid=TVSFVWD2ENXYGEJY&lid=LSTTVSFVWD2ENXYGEJYBNWSST&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&spotlightTagId=BestsellerId_ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=dac8f407-fc9b-4663-a9cf-64852b33a714.TVSFVWD2ENXYGEJY.SEARCH&ppt=None&ppn=None&ssid=yo3wkd98gw0000001679959275842&qH=c9a1fdac6e082dd8
# ...

# %%
product_link
# Out:
# 'https://www.flipkart.com/search?q=tv/samsung-80-cm-32-inch-hd-ready-led-smart-tizen-tv-2022-model/p/itm3c07ddc2dd25d?pid=TVSGHY2UZA9YHWQN&lid=LSTTVSGHY2UZA9YHWQNNQENTU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_H%2Ft1lVEmk5dG9Nh2WP4xGa987HtKQ%2F2Mh2fTcF92cwZEaLk1rTtsGNE8ePQkeIjzKUXLsS6xKC1eMMA2CJL5Kg%3D%3D&ppt=None&ppn=None&ssid=yo3wkd98gw0000001679959275842&qH=c9a1fdac6e082dd8'

# %%
product_req = requests.get(product_link)

# %%
product_req
# Out:
# <Response [200]>

# %%
product_req.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.103f43.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %%
product_html = bs(product_req.text, 'html.parser')

# %%
comment_box = product_html.find_all("div", {"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
comment_box[0].div.div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Abhijit Kar'

# %%
for i in comment_box:
  print(i.div.div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Abhijit Kar
# Sabarna Chakraborty
# Harjeet Malik
# Keerthana  Indrajith
# Vikas Rana
# malkeet mehra
# Hrithik Customer
# Vamsi Krishna Nittala
# Ankit Kumar
# Prakash Mukherjee
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-5a94a75113d3> in <module>
#       1 for i in comment_box:
# ----> 2   print(i.div.div.find_all("p", {"class": "_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
  print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 4
# 5
# 4
# 2
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-0254ef7ba63c> in <module>
#       1 for i in comment_box:
# ----> 2   print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comment_box:
  print(i.div.div.div.p.text)
# Out:
# Wonderful
# Brilliant
# Brilliant
# Worth every penny
# Delightful
# Fabulous!
# Worth the money
# Moderate
# Mind-blowing purchase
# Highly recommended
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-9e2f61593b4b> in <module>
#       1 for i in comment_box:
# ----> 2   print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.find_all("div",{"class":""})[0].div.text
# Out:
# "Nice tv within the budget. Sound quality is good, for picture quality I had to attach hdmi cable from set top box to tv. After that quality is pretty good.This tv did not come with a stand so I had only one option with the wall mount which I didn't like. Apart from that overall experience is good."

# %%
for i in comment_box:
  print(i.div.div.find_all("div",{"class":""})[0].div.text)
# Out:
# Nice tv within the budget. Sound quality is good, for picture quality I had to attach hdmi cable from set top box to tv. After that quality is pretty good.This tv did not come with a stand so I had only one option with the wall mount which I didn't like. Apart from that overall experience is good.
# Very Good Picture Quality with a decent sound system. You can surely go for this product in this price range. Good delivery by Flipkart.
# Nice one at this price good Samsung 🙏🙏🙏🙏My first Samsung led tv 📺 Befor I always use lg but this time Samsung I’m happy with Samsung led tv great job by Samsung and the Flipkart Thank you 🙏 Flipkart to deliver in this lockdown also little bit late but great work by Flipkart Good luck 😉
# Really awesome tv best quality very good sound... Just go for it guys bcz its very bettet than mi TV.  Very low prize best quality tv great and tqq flipkart
# ...
